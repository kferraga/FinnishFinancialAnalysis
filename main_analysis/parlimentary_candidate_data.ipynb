# %% [markdown]
# # Parliamentary Candidate Data

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

eduskuntavaalit_ehdokas_sarakkeet = list(pd.read_csv("files/Results_title_rows_EN_ehdokas.csv"))

years_data = {
    2011: {
        'results': "files/election_results_by_candidate/e-2011_teat_maa.csv"
    },
    2015: {
        'results': "files/election_results_by_candidate/e-2015_teat_maa.csv"
    },
    2019: {
        'results': "files/election_results_by_candidate/ekv-2019_teat_maa.csv"
    },
    2023: {
        'results': "files/election_results_by_candidate/ekv-2023_teat_maa.csv"
    }
}

def process_voting_data(years_data):
    """Function for preparing voting data to be municipal results only."""

    all_years_data = []
    for year, paths in years_data.items():
        print(f"Processing {year}...")

        kuntavaalit_ehdokas = pd.read_csv(paths['results'], sep=";", on_bad_lines='warn', encoding='latin-1', names=eduskuntavaalit_ehdokas_sarakkeet, index_col=False)

        kuntavaalit_ehdokas['Year'] = str(year) # Year column for classification later

        kuntavaalit_ehdokas["LR_cand-id"] = (
            kuntavaalit_ehdokas["Candidate number"].astype(str).str.strip() + "-" +
            kuntavaalit_ehdokas["Name of a municipality/electoral district/voting area in Finnish"].str.strip() + "-" + kuntavaalit_ehdokas["Area type"] + "-" + kuntavaalit_ehdokas['Year']
        )
        all_years_data.append(kuntavaalit_ehdokas)

    results = pd.concat(all_years_data, ignore_index=True)
    results = results.drop(results[results['Area type']!="V"].index) # K stands for the total municipal election
    return results

kuntavaalit_results = process_voting_data(years_data)
display(kuntavaalit_results)

# # Combine all years into one dataframe
#
# print(f"In total, there were {len(all_years_data[0])} candidates recorded from 2012; {len(all_years_data[1])} from 2017; {len(all_years_data[2])} from 2021; and {len(all_years_data[3])} from 2025.")
# Out:
# Processing 2011...
# C:\Users\kaife\AppData\Local\Temp\ipykernel_22108\1132518150.py:28: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   kuntavaalit_ehdokas = pd.read_csv(paths['results'], sep=";", on_bad_lines='warn', encoding='latin-1', names=eduskuntavaalit_ehdokas_sarakkeet, index_col=False)
# Processing 2015...
# C:\Users\kaife\AppData\Local\Temp\ipykernel_22108\1132518150.py:28: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   kuntavaalit_ehdokas = pd.read_csv(paths['results'], sep=";", on_bad_lines='warn', encoding='latin-1', names=eduskuntavaalit_ehdokas_sarakkeet, index_col=False)
# Processing 2019...
# C:\Users\kaife\AppData\Local\Temp\ipykernel_22108\1132518150.py:28: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   kuntavaalit_ehdokas = pd.read_csv(paths['results'], sep=";", on_bad_lines='warn', encoding='latin-1', names=eduskuntavaalit_ehdokas_sarakkeet, index_col=False)
# Processing 2023...
# C:\Users\kaife\AppData\Local\Temp\ipykernel_22108\1132518150.py:28: DtypeWarning: Columns (2,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   kuntavaalit_ehdokas = pd.read_csv(paths['results'], sep=";", on_bad_lines='warn', encoding='latin-1', names=eduskuntavaalit_ehdokas_sarakkeet, index_col=False)
#         Election type  Electoral district / county number Municipality number  \
# 42720            E                                      1                 ***
# 42721            E                                      1                 ***
# 42722            E                                      1                 ***
# 42723            E                                      1                 ***
# 42724            E                                      1                 ***
# ...               ...                                 ...                 ...
# 1987154          E                                     13                 ***
# 1987155          E                                     13                 ***
# 1987156          E                                     13                 ***
# 1987157          E                                     13                 ***
# 1987158          E                                     13                 ***
#
#         Area type Voting area identifier  \
# 42720           V                   ****
# 42721           V                   ****
# 42722           V                   ****
# 42723           V                   ****
# 42724           V                   ****
# ...           ...                    ...
# 1987154         V                   ****
# 1987155         V                   ****
# 1987156         V                   ****
# 1987157         V                   ****
# 1987158         V                   ****
#
#         Abbreviation for an electoral district / a county in Finnish  \
# 42720                                                  HEL
# 42721                                                  HEL
# 42722                                                  HEL
# 42723                                                  HEL
# 42724                                                  HEL
# ...                                                    ...
# 1987154                                                LAP
# 1987155                                                LAP
# 1987156                                                LAP
# 1987157                                                LAP
# 1987158                                                LAP
#
#         Abbreviation for an electoral district / a county in Swedish  \
# 42720                                                  HEL
# 42721                                                  HEL
# 42722                                                  HEL
# 42723                                                  HEL
# 42724                                                  HEL
# ...                                                    ...
# 1987154                                                LAP
# 1987155                                                LAP
# 1987156                                                LAP
# 1987157                                                LAP
# 1987158                                                LAP
#
#          Permanent party identifier  Standard party number  List order number  \
# 42720                            13                      5                  1
# 42721                            13                      5                  1
# 42722                            13                      5                  1
# 42723                            13                      5                  1
# 42724                            13                      5                  1
# ...                             ...                    ...                ...
# 1987154                        1315                     99                 15
# 1987155                        1315                     99                 15
# 1987156                        1315                     99                 15
# 1987157                        1315                     99                 15
# 1987158                        1315                     99                 15
#
#          Electoral alliance number  \
# 42720                            1
# 42721                            1
# 42722                            1
# 42723                            1
# 42724                            1
# ...                            ...
# 1987154                         14
# 1987155                         14
# 1987156                         14
# 1987157                         14
# 1987158                         14
#
#         Abbreviated name of a political party/group in Finnish  \
# 42720                                               VIHR
# 42721                                               VIHR
# 42722                                               VIHR
# 42723                                               VIHR
# 42724                                               VIHR
# ...                                                    ...
# 1987154                                             YL1
# 1987155                                             YL1
# 1987156                                             YL1
# 1987157                                             YL1
# 1987158                                             YL1
#
#         Abbreviated name of a political party/group in Swedish  \
# 42720                                               GRÖNA
# 42721                                               GRÖNA
# 42722                                               GRÖNA
# 42723                                               GRÖNA
# 42724                                               GRÖNA
# ...                                                    ...
# 1987154                                             YL1
# 1987155                                             YL1
# 1987156                                             YL1
# 1987157                                             YL1
# 1987158                                             YL1
#
#         Abbreviated name of a political party/group in English  \
# 42720                                               GREEN
# 42721                                               GREEN
# 42722                                               GREEN
# 42723                                               GREEN
# 42724                                               GREEN
# ...                                                    ...
# 1987154                                             YL1
# 1987155                                             YL1
# 1987156                                             YL1
# 1987157                                             YL1
# 1987158                                             YL1
#
#          Candidate number  \
# 42720                   2
# 42721                   3
# 42722                   4
# 42723                   5
# 42724                   6
# ...                   ...
# 1987154               109
# 1987155               110
# 1987156               111
# 1987157               112
# 1987158               113
#
#         Name of a municipality/electoral district/voting area in Finnish  \
# 42720             Helsingin vaalipiiri
# 42721             Helsingin vaalipiiri
# 42722             Helsingin vaalipiiri
# 42723             Helsingin vaalipiiri
# 42724             Helsingin vaalipiiri
# ...                                                    ...
# 1987154           Lapin vaalipiiri
# 1987155           Lapin vaalipiiri
# 1987156           Lapin vaalipiiri
# 1987157           Lapin vaalipiiri
# 1987158           Lapin vaalipiiri
#
#         Name of a municipality/electoral district/voting area in Swedish  \
# 42720             Helsingfors valkrets
# 42721             Helsingfors valkrets
# 42722             Helsingfors valkrets
# 42723             Helsingfors valkrets
# 42724             Helsingfors valkrets
# ...                                                    ...
# 1987154           Lapplands valkrets
# 1987155           Lapplands valkrets
# 1987156           Lapplands valkrets
# 1987157           Lapplands valkrets
# 1987158           Lapplands valkrets
#
#                                      A person’s first name  \
# 42720    Zahra                                         ...
# 42721    Outi                                          ...
# 42722    Verna                                         ...
# 42723    Pekka                                         ...
# 42724    Kimmo                                         ...
# ...                                                    ...
# 1987154  Juhani                                        ...
# 1987155  Jatta                                         ...
# 1987156  Jonna                                         ...
# 1987157  Krista                                        ...
# 1987158  Inkeri                                        ...
#
#                                       A person’s last name  Gender  \
# 42720    Abdulla                                       ...       2
# 42721    Alanko-Kahiluoto                              ...       2
# 42722    Castrén                                       ...       2
# 42723    Haavisto                                      ...       1
# 42724    Helistö                                       ...       1
# ...                                                    ...     ...
# 1987154  Mykkänen                                      ...       1
# 1987155  Mäkikyrö                                      ...       2
# 1987156  Pakisjärvi                                    ...       2
# 1987157  Stauffer                                      ...       2
# 1987158  Yritys                                        ...       2
#
#          Age on election day  \
# 42720                     45
# 42721                     44
# 42722                     21
# 42723                     53
# 42724                     49
# ...                      ...
# 1987154                   63
# 1987155                   37
# 1987156                   46
# 1987157                   45
# 1987158                   68
#
#                                                 Profession  \
# 42720    kätilö                                        ...
# 42721    kansanedustaja, tutkija                       ...
# 42722    opiskelija                                    ...
# 42723    kansanedustaja, ulkoministerin erityisedustaja...
# 42724    tuottaja                                      ...
# ...                                                    ...
# 1987154  eläkeläinen                                   ...
# 1987155  sairaanhoitaja YAMK                           ...
# 1987156  sairaanhoitaja                                ...
# 1987157  logistiikka-asiantuntija, kansainvälisten toim...
# 1987158  oikeusnotaari, kunnallisneuvos                ...
#
#          Code for place of residence  \
# 42720                             91
# 42721                             91
# 42722                             91
# 42723                             91
# 42724                             91
# ...                              ...
# 1987154                          698
# 1987155                          976
# 1987156                          241
# 1987157                          758
# 1987158                          261
#
#         The name of a place of residence in Finnish  \
# 42720      Helsinki
# 42721      Helsinki
# 42722      Helsinki
# 42723      Helsinki
# 42724      Helsinki
# ...                                             ...
# 1987154    Rovaniemi
# 1987155    Ylitornio
# 1987156    Keminmaa
# 1987157    Sodankylä
# 1987158    Kittilä
#
#         The name of a place of residence in Swedish Candidate’s language  \
# 42720      Helsingfors
# 42721      Helsingfors
# 42722      Helsingfors
# 42723      Helsingfors
# 42724      Helsingfors
# ...                                             ...                  ...
# 1987154    Rovaniemi                                                  FI
# 1987155    Övertorneå                                                 FI
# 1987156    Keminmaa                                                   FI
# 1987157    Sodankylä                                                  FI
# 1987158    Kittilä                                                    FI
#
#         Member of the European Parliament Member of Parliament  \
# 42720
# 42721                                                        1
# 42722
# 42723                                                        1
# 42724
# ...                                   ...                  ...
# 1987154
# 1987155
# 1987156
# 1987157
# 1987158
#
#         Municipal councillor County councillor  \
# 42720
# 42721
# 42722
# 42723
# 42724
# ...                      ...               ...
# 1987154
# 1987155
# 1987156                    1
# 1987157                    1                 1
# 1987158                    1                 1
#
#         Abbreviated name of the first comparison election  \
# 42720
# 42721
# 42722
# 42723
# 42724
# ...                                                   ...
# 1987154                                        EKV-2019
# 1987155                                        EKV-2019
# 1987156                                        EKV-2019
# 1987157                                        EKV-2019
# 1987158                                        EKV-2019
#
#         Number of votes in the first comparison election  \
# 42720                                            0000000
# 42721                                            0000000
# 42722                                            0000000
# 42723                                            0000000
# 42724                                            0000000
# ...                                                  ...
# 1987154                                          0000000
# 1987155                                          0000000
# 1987156                                          0000000
# 1987157                                          0000000
# 1987158                                          0000000
#
#          Number of votes cast in advance  \
# 42720                               1517
# 42721                               1726
# 42722                                266
# 42723                               3026
# 42724                                229
# ...                                  ...
# 1987154                                9
# 1987155                               66
# 1987156                              148
# 1987157                               96
# 1987158                              174
#
#          Number of votes cast on election day  Total number of votes  \
# 42720                                    2045                   3562
# 42721                                    3514                   5240
# 42722                                     429                    695
# 42723                                    4444                   7470
# 42724                                     469                    698
# ...                                       ...                    ...
# 1987154                                     1                     10
# 1987155                                    39                    105
# 1987156                                    92                    240
# 1987157                                    80                    176
# 1987158                                    91                    265
#
#          Percentage (%) of votes cast in advance  \
# 42720                                         11
# 42721                                         12
# 42722                                          2
# 42723                                         21
# 42724                                          2
# ...                                          ...
# 1987154                                        0
# 1987155                                        1
# 1987156                                        2
# 1987157                                        1
# 1987158                                        3
#
#          Percentage (%) of votes on election day  \
# 42720                                         10
# 42721                                         17
# 42722                                          2
# 42723                                         22
# 42724                                          2
# ...                                          ...
# 1987154                                        0
# 1987155                                        1
# 1987156                                        3
# 1987157                                        2
# 1987158                                        3
#
#          Percentage (%) of the total number of votes  Elected information  \
# 42720                                             10                    3
# 42721                                             15                    1
# 42722                                              2                    3
# 42723                                             21                    1
# 42724                                              2                    3
# ...                                              ...                  ...
# 1987154                                            0                    3
# 1987155                                            1                    3
# 1987156                                            2                    3
# 1987157                                            2                    3
# 1987158                                            3                    3
#
#          Comparative index  Position  Final position Calculation status  \
# 42720              7254000        45              45                  V
# 42721             14508000        21              21                  V
# 42722              3054316        97              97                  V
# 42723             19344000        14              14                  V
# 42724              3224000        94              94                  V
# ...                    ...       ...             ...                ...
# 1987154             153875       102             102                  V
# 1987155             205167        97              97                  V
# 1987156             410333        83              83                  V
# 1987157             307750        89              89                  V
# 1987158             615500        79              79                  V
#
#         Calculation phase   Latest update  Year                     LR_cand-id
# 42720                   T  20131212175905  2011  2-Helsingin vaalipiiri-V-2011
# 42721                   T  20131212175905  2011  3-Helsingin vaalipiiri-V-2011
# 42722                   T  20131212175905  2011  4-Helsingin vaalipiiri-V-2011
# 42723                   T  20131212175905  2011  5-Helsingin vaalipiiri-V-2011
# 42724                   T  20131212175905  2011  6-Helsingin vaalipiiri-V-2011
# ...                   ...             ...   ...                            ...
# 1987154                 T  20230405170638  2023    109-Lapin vaalipiiri-V-2023
# 1987155                 T  20230405170638  2023    110-Lapin vaalipiiri-V-2023
# 1987156                 T  20230405170638  2023    111-Lapin vaalipiiri-V-2023
# 1987157                 T  20230405170638  2023    112-Lapin vaalipiiri-V-2023
# 1987158                 T  20230405170638  2023    113-Lapin vaalipiiri-V-2023
#
# [9353 rows x 47 columns]

# %%
print(kuntavaalit_results["Total number of votes"].describe())
print(len(pd.unique(kuntavaalit_results["LR_cand-id"])))
# kuntavaalit_results["A person’s last name"] = kuntavaalit_results["A person’s last name"].strip()
display(kuntavaalit_results.loc[kuntavaalit_results["A person’s last name"].astype(str).str.strip() == "Mäkikyrö"])
# Out:
# count     9353.000000
# mean      1292.157917
# std       2368.212544
# min          1.000000
# 25%        110.000000
# 50%        432.000000
# 75%       1390.000000
# max      43437.000000
# Name: Total number of votes, dtype: float64
# 9353
#         Election type  Electoral district / county number Municipality number  \
# 1987155          E                                     13                 ***
#
#         Area type Voting area identifier  \
# 1987155         V                   ****
#
#         Abbreviation for an electoral district / a county in Finnish  \
# 1987155                                                LAP
#
#         Abbreviation for an electoral district / a county in Swedish  \
# 1987155                                                LAP
#
#          Permanent party identifier  Standard party number  List order number  \
# 1987155                        1315                     99                 15
#
#          Electoral alliance number  \
# 1987155                         14
#
#         Abbreviated name of a political party/group in Finnish  \
# 1987155                                             YL1
#
#         Abbreviated name of a political party/group in Swedish  \
# 1987155                                             YL1
#
#         Abbreviated name of a political party/group in English  \
# 1987155                                             YL1
#
#          Candidate number  \
# 1987155               110
#
#         Name of a municipality/electoral district/voting area in Finnish  \
# 1987155           Lapin vaalipiiri
#
#         Name of a municipality/electoral district/voting area in Swedish  \
# 1987155           Lapplands valkrets
#
#                                      A person’s first name  \
# 1987155  Jatta                                         ...
#
#                                       A person’s last name  Gender  \
# 1987155  Mäkikyrö                                      ...       2
#
#          Age on election day  \
# 1987155                   37
#
#                                                 Profession  \
# 1987155  sairaanhoitaja YAMK                           ...
#
#          Code for place of residence  \
# 1987155                          976
#
#         The name of a place of residence in Finnish  \
# 1987155    Ylitornio
#
#         The name of a place of residence in Swedish Candidate’s language  \
# 1987155    Övertorneå                                                 FI
#
#         Member of the European Parliament Member of Parliament  \
# 1987155
#
#         Municipal councillor County councillor  \
# 1987155
#
#         Abbreviated name of the first comparison election  \
# 1987155                                        EKV-2019
#
#         Number of votes in the first comparison election  \
# 1987155                                          0000000
#
#          Number of votes cast in advance  \
# 1987155                               66
#
#          Number of votes cast on election day  Total number of votes  \
# 1987155                                    39                    105
#
#          Percentage (%) of votes cast in advance  \
# 1987155                                        1
#
#          Percentage (%) of votes on election day  \
# 1987155                                        1
#
#          Percentage (%) of the total number of votes  Elected information  \
# 1987155                                            1                    3
#
#          Comparative index  Position  Final position Calculation status  \
# 1987155             205167        97              97                  V
#
#         Calculation phase   Latest update  Year                   LR_cand-id
# 1987155                 T  20230405170638  2023  110-Lapin vaalipiiri-V-2023

# %%
kuntavaalit_municipal_candidates = kuntavaalit_results.groupby(['Name of a municipality/electoral district/voting area in Finnish', 'Year']).agg(num_candidates=('Year', 'size'), total_votes=('Total number of votes', 'sum')).reset_index()
kuntavaalit_municipal_candidates["Name of a municipality/electoral district/voting area in Finnish"] = kuntavaalit_municipal_candidates["Name of a municipality/electoral district/voting area in Finnish"].str.strip()

kuntavaalit_results.to_csv("files/outputs/parliamentary_election_results_by_candidate.csv")
kuntavaalit_municipal_candidates.to_csv("files/outputs/parliamentary_macro_per_year.csv")

display(kuntavaalit_municipal_candidates)
# Out:
#    Name of a municipality/electoral district/voting area in Finnish  Year  \
# 0                    Ahvenanmaan maakunnan vaalipiiri                2011
# 1                    Ahvenanmaan maakunnan vaalipiiri                2015
# 2                    Ahvenanmaan maakunnan vaalipiiri                2019
# 3                    Ahvenanmaan maakunnan vaalipiiri                2023
# 4                              Etelä-Savon vaalipiiri                2011
# 5                                Helsingin vaalipiiri                2011
# 6                                Helsingin vaalipiiri                2015
# 7                                Helsingin vaalipiiri                2019
# 8                                Helsingin vaalipiiri                2023
# 9                                   Hämeen vaalipiiri                2011
# 10                                  Hämeen vaalipiiri                2015
# 11                                  Hämeen vaalipiiri                2019
# 12                                  Hämeen vaalipiiri                2023
# 13                         Kaakkois-Suomen vaalipiiri                2015
# 14                         Kaakkois-Suomen vaalipiiri                2019
# 15                         Kaakkois-Suomen vaalipiiri                2023
# 16                            Keski-Suomen vaalipiiri                2011
# 17                            Keski-Suomen vaalipiiri                2015
# 18                            Keski-Suomen vaalipiiri                2019
# 19                            Keski-Suomen vaalipiiri                2023
# 20                                   Kymen vaalipiiri                2011
# 21                                   Lapin vaalipiiri                2011
# 22                                   Lapin vaalipiiri                2015
# 23                                   Lapin vaalipiiri                2019
# 24                                   Lapin vaalipiiri                2023
# 25                                   Oulun vaalipiiri                2011
# 26                                   Oulun vaalipiiri                2015
# 27                                   Oulun vaalipiiri                2019
# 28                                   Oulun vaalipiiri                2023
# 29                              Pirkanmaan vaalipiiri                2011
# 30                              Pirkanmaan vaalipiiri                2015
# 31                              Pirkanmaan vaalipiiri                2019
# 32                              Pirkanmaan vaalipiiri                2023
# 33                        Pohjois-Karjalan vaalipiiri                2011
# 34                           Pohjois-Savon vaalipiiri                2011
# 35                              Satakunnan vaalipiiri                2011
# 36                              Satakunnan vaalipiiri                2015
# 37                              Satakunnan vaalipiiri                2019
# 38                              Satakunnan vaalipiiri                2023
# 39                           Savo-Karjalan vaalipiiri                2015
# 40                           Savo-Karjalan vaalipiiri                2019
# 41                           Savo-Karjalan vaalipiiri                2023
# 42                               Uudenmaan vaalipiiri                2011
# 43                               Uudenmaan vaalipiiri                2015
# 44                               Uudenmaan vaalipiiri                2019
# 45                               Uudenmaan vaalipiiri                2023
# 46                                  Vaasan vaalipiiri                2011
# 47                                  Vaasan vaalipiiri                2015
# 48                                  Vaasan vaalipiiri                2019
# 49                                  Vaasan vaalipiiri                2023
# 50                        Varsinais-Suomen vaalipiiri                2011
# 51                        Varsinais-Suomen vaalipiiri                2015
# 52                        Varsinais-Suomen vaalipiiri                2019
# 53                        Varsinais-Suomen vaalipiiri                2023
#
#     num_candidates  total_votes
# 0                8        10503
# 1                7        12187
# 2                5        13076
# 3               15        13383
# 4               94        83432
# 5              267       347885
# 6              269       359875
# 7              286       385560
# 8              293       388501
# 9              132       202689
# 10             127       202446
# 11             155       205738
# 12             144       207266
# 13             149       245545
# 14             179       244974
# 15             158       228628
# 16             141       148433
# 17             127       151269
# 18             153       154375
# 19             146       153254
# 20             118       169102
# 21             114        99357
# 22             118       100871
# 23             122        99807
# 24             112        97904
# 25             156       243662
# 26             165       249652
# 27             184       258858
# 28             177       261715
# 29             207       273920
# 30             203       278073
# 31             251       299154
# 32             239       309941
# 33             108        87185
# 34             118       131369
# 35              97       126108
# 36             126       122334
# 37             117       124871
# 38             124       119611
# 39             139       216880
# 40             165       221529
# 41             156       224357
# 42             406       507189
# 43             394       520119
# 44             492       546672
# 45             485       565306
# 46             158       248881
# 47             156       245817
# 48             168       250901
# 49             161       246966
# 50             191       259856
# 51             166       263394
# 52             191       276401
# 53             214       278772
