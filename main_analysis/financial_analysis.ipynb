# %% [markdown]
# # Financial Analysis
#
# The main jupyter notebook for the analysis of Finnish election candidate finances. *This will, in all likelihood, not remain one file once exploration is complete*. Potential avenues include:
# - General regression analysis, observing how much different factors at play (where a candidate got their money from, how they spent it, and other correlatory effects impacted the election results).
#     - Previously held electoral experience, financial information
# - Isolate anomalies, or people outside of the norm. I.e. Candidate 8 appears to have been very successful even though they spent very little, why is that?
# - Who funds who, who spends where based on party, age
# - Comparison on effectiveness for different types of ad spending
# - Whether self funding is useful/successful
#
# Important drawbacks to remember:
# - This information only focuses on the winners of the election, rather then the losers. May be a winner bias, i.e. losers did spend more on self fundraising but those candidates who were already successful used it more effectively.
# - Correlation != causuation and information can make things worse. Obvious but I'm writing it anyways because it must always be kept in mind.

# %%
import pandas as pd

kuntavaalit_2012 = pd.read_csv("files/finances/Liite_10_Kuntavaalit_2012_VI.csv", sep=";", on_bad_lines='warn')
# display(kuntavaalit_2012)
display(kuntavaalit_2012[5375:5378])
# Out:
# C:\Users\kaife\AppData\Local\Temp\ipykernel_13384\759165653.py:3: ParserWarning: Skipping line 188: expected 41 fields, saw 42
# Skipping line 256: expected 41 fields, saw 43
# Skipping line 325: expected 41 fields, saw 43
# Skipping line 794: expected 41 fields, saw 42
# Skipping line 953: expected 41 fields, saw 43
# Skipping line 1289: expected 41 fields, saw 42
# Skipping line 1646: expected 41 fields, saw 44
# Skipping line 1730: expected 41 fields, saw 42
# Skipping line 2028: expected 41 fields, saw 42
# Skipping line 2315: expected 41 fields, saw 42
# Skipping line 2544: expected 41 fields, saw 42
# Skipping line 2661: expected 41 fields, saw 43
# Skipping line 2952: expected 41 fields, saw 42
# Skipping line 2962: expected 41 fields, saw 42
# Skipping line 3204: expected 41 fields, saw 44
# Skipping line 3963: expected 41 fields, saw 42
# Skipping line 4034: expected 41 fields, saw 42
# Skipping line 4693: expected 41 fields, saw 42
# Skipping line 4697: expected 41 fields, saw 42
# Skipping line 4726: expected 41 fields, saw 43
# Skipping line 4961: expected 41 fields, saw 42
# Skipping line 4979: expected 41 fields, saw 43
# Skipping line 5046: expected 41 fields, saw 42
# Skipping line 5271: expected 41 fields, saw 43
# Skipping line 5376: expected 41 fields, saw 45
# Skipping line 5877: expected 41 fields, saw 42
# Skipping line 6206: expected 41 fields, saw 42
# Skipping line 6209: expected 41 fields, saw 42
# Skipping line 6695: expected 41 fields, saw 42
# Skipping line 7038: expected 41 fields, saw 43
# Skipping line 7173: expected 41 fields, saw 42
# Skipping line 8182: expected 41 fields, saw 42
# Skipping line 9569: expected 41 fields, saw 42
# Skipping line 9637: expected 41 fields, saw 43
# Skipping line 9790: expected 41 fields, saw 43
# Skipping line 10085: expected 41 fields, saw 42
# Skipping line 10463: expected 41 fields, saw 46
# Skipping line 10860: expected 41 fields, saw 42
# Skipping line 11472: expected 41 fields, saw 42
# Skipping line 11795: expected 41 fields, saw 44
# Skipping line 12439: expected 41 fields, saw 42
# Skipping line 12508: expected 41 fields, saw 42
# Skipping line 13314: expected 41 fields, saw 42
# Skipping line 13368: expected 41 fields, saw 42
# Skipping line 13519: expected 41 fields, saw 43
# Skipping line 13648: expected 41 fields, saw 45
# Skipping line 13676: expected 41 fields, saw 42
# Skipping line 13871: expected 41 fields, saw 43
# Skipping line 14312: expected 41 fields, saw 43
# Skipping line 14440: expected 41 fields, saw 43
# Skipping line 14607: expected 41 fields, saw 42
# Skipping line 14750: expected 41 fields, saw 42
# Skipping line 14995: expected 41 fields, saw 43
# Skipping line 15279: expected 41 fields, saw 43
# Skipping line 15301: expected 41 fields, saw 42
# Skipping line 15408: expected 41 fields, saw 43
# Skipping line 16436: expected 41 fields, saw 42
#
#   kuntavaalit_2012 = pd.read_csv("files/finances/Liite_10_Kuntavaalit_2012_VI.csv", sep=";", on_bad_lines='warn')
# C:\Users\kaife\AppData\Local\Temp\ipykernel_13384\759165653.py:3: ParserWarning: Skipping line 16542: expected 41 fields, saw 43
# Skipping line 16879: expected 41 fields, saw 42
# Skipping line 17100: expected 41 fields, saw 43
# Skipping line 17384: expected 41 fields, saw 43
# Skipping line 17752: expected 41 fields, saw 42
# Skipping line 18201: expected 41 fields, saw 42
# Skipping line 18338: expected 41 fields, saw 42
# Skipping line 18859: expected 41 fields, saw 43
# Skipping line 18911: expected 41 fields, saw 44
# Skipping line 18935: expected 41 fields, saw 42
#
#   kuntavaalit_2012 = pd.read_csv("files/finances/Liite_10_Kuntavaalit_2012_VI.csv", sep=";", on_bad_lines='warn')
#      'Ehdokasnumero' 'Kuntanumero'           'Etunimet'     'Sukunimi'  \
# 5375          '0386'         '049'  'Janna Kirsi Elina'     'Koivisto'
# 5376          '0415'         '049'     'Jyrki Johannes'  'Myllärniemi'
# 5377          '0448'         '049'        'Mika Pertti'     'Soininen'
#
#                                  'Arvo/ammatti/tehtava' 'Vaalipiiri/Kunta'  \
# 5375  'yhteiskuntatieteen maisteri, kansainvälisten ...            'Espoo'
# 5376                         'Diakoni, sosionomi yamk.'            'Espoo'
# 5377                                  'lastenpsykiatri'            'Espoo'
#
#      'Puolue' 'Ehdokkaan mahdollisen tukiryhman nimi'  \
# 5375   'VIHR'                                      ''
# 5376   'VIHR'                                      ''
# 5377   'VIHR'                                      ''
#
#      'Vaalirahoitukseni ei ole ylittanyt 800 euroa'  \
# 5375                                            'X'
# 5376                                             ''
# 5377                                            'X'
#
#      'Vaalikampanjan kulut yhteensa'  ...  \
# 5375                              ''  ...
# 5376                          '2982'  ...
# 5377                              ''  ...
#
#      '2.5 Ei sisalla yhtaan vahintaan 800 euron tukisuoritusta puolueelta ("x")'  \
# 5375                                                ' '
# 5376                                                'X'
# 5377                                                ' '
#
#      '2.5 Rahoitus sisaltaa puolueelta saatua tukea yhteensa lisatietokentan teksti'  \
# 5375                                                 ''
# 5376                                                 ''
# 5377                                                 ''
#
#      '2.6 Rahoitus sisaltaa puolueyhdistyksilta saatua tukea yhteensa'  \
# 5375                                                 ''
# 5376                                                 ''
# 5377                                                 ''
#
#      '2.6 Ei sisalla yhtaan vahintaan 800 euron tukisuoritusta puolueyhdistyksilta ("x")'  \
# 5375                                                ' '
# 5376                                                'X'
# 5377                                                ' '
#
#      '2.6 Rahoitus sisaltaa puolueyhdistyksilta saatua tukea yhteensa lisatietokentan teksti'  \
# 5375                                                 ''
# 5376                                                 ''
# 5377                                                 ''
#
#      '2.7 Rahoitus sisaltaa muilta tahoilta saatua tukea yhteensa'  \
# 5375                                                 ''
# 5376                                                 ''
# 5377                                                 ''
#
#      '2.7 Ei sisalla yhtaan vahintaan 800 euron tukisuoritusta muilta tahoilta ("x")'  \
# 5375                                                ' '
# 5376                                                'X'
# 5377                                                ' '
#
#      '2.7 Rahoitus sisaltaa muilta tahoilta saatua tukea yhteensa lisatietokentan teksti'  \
# 5375                                                 ''
# 5376                                                 ''
# 5377                                                 ''
#
#      '2.8 Rahoitus sisaltaa valitettya tukea yhteensa'  \
# 5375                                                ''
# 5376                                                ''
# 5377                                                ''
#
#      'E. vapaaehtoinen erittely'
# 5375                          ''
# 5376                          ''
# 5377                          ''
#
# [3 rows x 41 columns]

# %%
import csv

with open('files/finances/Liite_10_Kuntavaalit_2012_VI.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f, delimiter=";")
    header = next(reader)
    print(f"Header has {len(header)} fields")
    
    problem_lines = [256, 325, 794, 953, 1289, 1646, 1730, 2028, 
                     2315, 2544, 2661, 2952, 2962, 3204, 3963, 4034,
                     4693, 4697, 4726, 4961, 4979, 5046, 5271, 5376]
    
    for i, row in enumerate(reader, start=2):  # start=2 because header is line 1
        if i in problem_lines:
            print(f"\nLine {i}: {len(row)} fields")
            print(f"Raw content: {row}")
            # Show which fields might be problematic
            if len(row) > 41:
                # for val in row[41:]:
                #     print(val)
                print(f"Extra fields: {row[41:]}")
# Out:
# Header has 1 fields
#
# Line 256: 7 fields
# Raw content: ["'0204';'980';'Esko Tapani';'Morikka';'lehtori", " eläkeläinen';'Ylöjärvi';'PS';'';'';'2114", "90';'777", "49';'';'';'';'';'';'312", "42';'';'';'';'1025';'2114", "90';'2114", "90';'';'';'X';'';'';'X';'';'';'X';'';'';'X';'';'';'X';'';'';'1. Vaalikampanjan kulut yhteensä - Muut kulut: Avustus paikallisyhd. 1000 € ja &quot;lisenssimaksu&quot;'"]
#
# Line 325: 7 fields
# Raw content: ["'0086';'205';'Eila Anneli';'Aavakare';'kauppateknikko", " hyvinvointiterapeutti';'Kajaani';'PS';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'1. Vaalikampanjan kulut yhteensä 755 eur - Vaalimainonta: Sanoma-", ' ilmaisjakelu- ja aikakauslehdet 244 eur; Ulkomainonta 13', '00 eur; Vaalilehtien', ' esitteiden ja muun painetun materiaalin hankinta 369', '00 eur - Vaalitilaisuudet 129', "00 eur 2. Vaalikampanjan rahoitus yhteensä 755 eur 2.1 Rahoitus sisältää omia varoja yhteensä 755 eur'"]
#
# Line 794: 8 fields
# Raw content: ["'0015';'211';'Akseli Iivari';'Kettula';'opiskelija';'Kangasala';'KOK';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'Kampanjani rahoitin omilla varoillani. Tilasin 1500kpl käyntikortteja", ' jotka maksoivat 22€ plus toimituskulut (30', '81€). Sen lisäksi ostin mainoksen Kangasalan Sanomien silmäkulmaan. Se maksoi 200€+alv = 246€. Matkakuluja kertyi vähän', ' koska kuljin omalla autollani ja kävellen. Kaikki henkilökohtaiset kulut', ' jotka liittyvät kampanjaani', ' ovat tässä. Lisäksi yhteisillä mainoksilla ja tapahtumilla kampanjaani tuki Kangasalan Kokoomus r.y.; Kangasalan Kokoomuksen Nuoret r.y. ja Pirkanmaan Kokoomusnuoret r.y. Näitä kuluja ei laskettane ehdokkaan omaan budjettiin', ' koska ne eivät suuntautuneet henkilökohtaiseen mainontaan', " vaan yhdistysten ehdokkaiden yhteiseen mainontaan. Henkilökohtaista kannatusyhdistystä minulla ei ollut.'"]
#
# Line 953: 6 fields
# Raw content: ["'0025';'604';'Armi Elisabet';'Kärki';'lehtori", " ammatinopettaja';'Pirkkala';'PS';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'Pirkkaan kunta; Pirkkalainen-lehti mainos 33", '25 euroa sekä vaalikone 17', '19 euroa      Perussuomalaiset; 30 euroa      Perussuomalaiset Naiset 100 euroa      Pirkanmaan Perussuomaaiset 30 euroa sekä 33', '33 euroa      Yhteensä 243', "77 euroa  '"]
#
# Line 1289: 2 fields
# Raw content: ["'0022';'420';'Marjo-Nina';'Mustonen';'Taidelasiyrittäjä", " järjestyksenvalvoja';'Leppävirta';'KESK';'Murun tukiryhmä';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'Henkilökohtainen vaalibudjettini oli paikallisosaston määräämä kaikkien ehdokkaiden suorittama 100€.      Lisäksi tukiryhmäni osti 2 mainosta paikallislehdestä; yht. 150€.'"]
#
# Line 1646: 6 fields
# Raw content: ["'0022';'249';'Kaija Aliina';'Asunmaa';'sosiaaliohjaaja", " hoitaja';'Keuruu';'KESK';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'2 ilmoitusta Suur-Keuruu lehdessä 2 x 88", '80. Suur-Keuruun sivuilla (ilmoitus) &quot;nonstoppina&quot; muiden ehdokkaiden kanssa 24h/vrk 7 € x 1vrk ajalla 17.10.2012-27.10.2012)=11 pv 7 € x 11pv=77 eur sis. laskutuslisän 4', '14 € sis.arvonlisäveroa 23% 59', '50 -&gt; 318', "24 eur. Lisäksi: JHL paikallisen Keuruun osasto maksoi 2 ilmoitusta Suur-Keuruu lehdessä (henkilökohtaista ilmoitusta)'"]
#
# Line 1730: 2 fields
# Raw content: ["'0015';'785';'Meeri Hilja Kaarina';'Keränen';'sairaanhoitaja';'Vaala';'KESK';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'- lehti-ilmoitus 85", "02 € -&gt; itse maksanut.'"]
#
# Line 2028: 4 fields
# Raw content: ["'0142';'851';'Miia Marjaana';'Luonua-Bajrami';'lähihoitaja", " kasv.tiet.yo';'Tornio';'KESK';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'1. Vaalikampanjan kulut yhteensä noin 300 eur. Vaalimainonta: Sanoma-", ' ilmaisjakelu- ja aikakauslehdet 30 eur; Vaalilehtien', " esitteiden ja muun painetun materiaalin hankinta 270 eur 2. Vaalikampanjan rahoitus yhteensä 2.1 Rahoitus sisältää omia varoja yhteensä noin 300 eur'"]
#
# Line 2315: 18 fields
# Raw content: ["'0078';'165';'Satu Hannele';'Koskela';'VTM", " perusturvan kehitysjohtaja';'Janakkala';'SDP';'';'';'841", "49';'441", "49';'0';'0';'0';'0';'0';'400", "00';'0';'0';'0';'0';'841", "49';'641", "49';'0';'0';'X';'';'0';'X';'';'0';'X';'';'200", "00';'X';'Turengin Sosialidemokraatit -puolueyhdistyksen tuki 200 euroa", "';'0';'X';'';'0';'Mainos kunnallisjärjestön tuottamassa vaalilehdessä 200 euroa sisältyy kohtaan Vaalilehtien", ' esitteiden ja muun painetun materiaalin hankinta. Mainoskortteja 2000 kpl', ' yht. 200 euroa sisältyy kohtaan Vaalilehtien', ' esitteiden ja muun painetun materiaalin hankinta. Mainos Janakkalan Sanomissa 18.10. yht. 366', '41 euroa sekä vaalien jälkeinen kiitosilmoitus samassa lehdessä 1.11. 75', '08 euroa sisältyy kohtaan Sanoma', ' ilmaisjakelu- ja aikakauslehdet. Turengin Sosialidemokraatit tuki alueensa ehdokkaita 200 eurolla; sisältyy kohtaan puolueyhdistysten tuki. Menot yhteensä 841', '49 euroa', ' tulot 200 euroa. Erotus omaa rahoitusta: 641', "49.'"]
#
# Line 2544: 4 fields
# Raw content: ["'0051';'005';'Kaarina';'Paalijärvi';'eläkeläinen", " emäntä';'Alajärvi';'KOK';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'1. Vaalikampanjan kulut yhteensä 360 eur - Vaalimainonta: Sanoma-", ' ilmaisjakelu- ja aikakauslehdet 150 eur; Vaalilehtien', " esitteiden ja muun painetun materiaalin hankinta 100 eur 2. Vaalikampanjan rahoitus yhteensä 2.1 Rahoitus sisältää omia varoja yhteensä 110 eur 2.3 Rahoitus sisältää yksityishenkilöiltä saatua tukea yhteensä 150 eur 2.5 Rahoitus sisältää puolueelta saatua tukea yhteensä 100 eur'"]
#
# Line 2661: 4 fields
# Raw content: ["'0052';'678';'Reijo Armas';'Härönoja';'työsuhdepäällikkö", " eläkeläinen';'Raahe';'KESK';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'Raahen keskusta kunnallisjärjestö on käyttänyt rahaa kaikkien 64 ehdokkaan tukemiseen mm. yhteismainoksilla 109€ / ehdokas", ' sen lisäksi olen itse maksanut ehdokaskuvasta 30€', " joten ennakkoilmoitukseni 100€ &quot;pitää kutinsa&quot; koska en tiennyt ilmoitetaanko yhdistyksen osuus?'"]
#
# Line 2952: 1 fields
# Raw content: ["'0105';'139';'Helka Tellervo';'Tapio';'Taloussihteeri';'Ii';'KESK';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'Paikallislehti Rantapohja 65 euroa ilmoitus/mainos<br />Paikallislehti Rantapohja; 11 euroa Kiitos ilmoitus'"]
#
# Line 2962: 6 fields
# Raw content: ["'0274';'285';'Irma Linnea';'Rajantie';'Eläkeläinen';'Kotka';'SDP';'(Asta Kankaanpää", " Leena Kömi)';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'1. Vaalikampanjan kulut yhteensä 300 eur - Vaalimainonta: Sanoma-", ' ilmaisjakelu- ja aikakauslehdet 258', '40 eur; Vaalilehtien', ' esitteiden ja muun painetun materiaalin hankinta 41', "60 eur 2. Vaalikampanjan rahoitus yhteensä 300 eur 2.6 Rahoitus sisältää puolueyhdistykseltä saatua tukea yhteensä 300 eur'"]
#
# Line 3204: 2 fields
# Raw content: ["'0070';'164';'Eija Inkeri';'Mäntymäki';'tekniikan insinööri YAMK", " eläkeläinen';'Jalasjärvi';'KESK';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'50 €; kunnallisjärjestön yhteismainoksiin<br />150 €; itsemaksetut mainokset ja käyntikortit<br />100 €; saatu lahjoitettu mainos<br />300 € yht.'"]
#
# Line 3963: 6 fields
# Raw content: ["'0026';'142';'Hannu Henrik';'Suhonen';'merkonomi", " kunnanvaltuutettu';'Iitti';'VAS';'ei ollut';'';'1010';'';'';'';'';'';'260';'300';'';'100';'';'350';'1125';'1075';'';'50';' ';'';'';' ';'Ei saatu yritysmaailmaa", " Ei tue komm';'';' ';'';'';' ';'';'';' ';'';'';'Vaalilehtien", ' esitteiden ja muun painetun materiaalin hankinta (vaali kynät) 280: -esítteet 300:-<br />Muut kulut (Mainosten jakelu', ' tilaisuudet Bensiini ym kulut). Puolueelta saatua tukea 825 €; käytetty 5 ehdokkaan yhteisiin vaali-ilmoituskuluihin (825 € jakautuu 5 ehdokkaalle)', " Vaali-ilmoituskulut sisältävät vas1. Iitin kunnallisjärj. asettamien 5 ehdokkaan kulut.<br />(ilmoitus Lehti Iitin seutu ei muita lehtiä)'"]
#
# Line 4034: 3 fields
# Raw content: ["'0141';'153';'Seppo Kalevi';'Skyttä';'insinööri", " eläkkeellä';'Imatra';'KOK';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'Imatrankokoomuksenkunnallisjärjestö;407", "21eur'"]
#
# Line 4693: 13 fields
# Raw content: ["'0007';'408';'Seppo Vilho Sakari';'Kärki';'käyttöpäällikkö", " maanviljelijä';'Lapua';'PS';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'Perussuomalaisten jäsenmaksu 25 €", ' Dieselpolttoöljy 25 €', ' tarvikkeet + muut 6 €. 1. Vaalikampanjan kulut yhteensä 56', '00 eur - Vaalimainonta: Sanoma-', ' ilmaisjakelu- ja aikakauslehdet (puolueen lehti ?); Vaalilehtien', ' esitteiden ja muun painetun materiaalin hankinta 10', '00 eur - Muut kulut 46', '00 eur. 2. Vaalikampanjan rahoitus yhteensä 2.1 Rahoitus sisältää omia varoja yhteensä 56', '00 eur 2.5 Rahoitus sisältää puolueelta saatua tukea yhteensä ? c. Lisätietoja: Perussuomalainen lehti', ' Vaasan vaalipiirin liitteellä', ' jaossa Lapualla. Yhteismainoksia Lapuan Sanomissa', " Lapuan linkissä jonka Perussuomalaisten Etelä-Pohjanmaan piiri kustansi/Perussuomalaiset puolue kustansi.'"]
#
# Line 4697: 4 fields
# Raw content: ["'0025';'408';'Arvi Johannes';'Välkkilä';'työnjohtaja", " eläkeläinen';'Lapua';'VAS';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'1. Vaalikampanjan kulut yhteensä 400 eur - Vaalimainonta: Sanoma-", ' ilmaisjakelu- ja aikakauslehdet 200 eur; Vaalilehtien', " esitteiden ja muun painetun materiaalin hankinta 200 eur 2. Vaalikampanjan rahoitus yhteensä 400 eur 2.1 Rahoitus sisältää omia varoja yhteensä 200 eur 2.6 Rahoitus sisältää puolueyhdistyksiltä saatua tukea yhteensä 200 eur'"]
#
# Line 4726: 2 fields
# Raw content: ["'0050';'408';'Kari Hannu Tapani';'Hakomäki';'asentaja';'Lapua';'KESK';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'Mainokset 274", "39 € (lehdessä) omasta &quot;pussista&quot;<br />Arvioitu muu tuki 150 €'"]
#
# Line 4961: 12 fields
# Raw content: ["'0129';'598';'Richard John Edvard';'Sjölund';'rektor", " pensionär';'Pietarsaari';'SDP';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'Jakobstads sv. asbetarf. annons; broshyr 417", '85. Andelslaget Folkhemmet', ' visitkort 9', '40. Soc.dem. samarbetsorg', ' evenemang gågatan 35', '10. Egna medel', ' visitkort 56', '58. Egna medel', ' tackannons 142', '38. = 661', "31'"]
#
# Line 4979: 1 fields
# Raw content: ["'0069';'598';'Bo Sten Ingmar';'Forsman';'pensionär';'Pietarsaari';'RKP';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'200 e egen finansiering + 443;11 gemensam finansiering = 643;11'"]
#
# Line 5046: 3 fields
# Raw content: ["'0008';'149';'Lassi';'Koikkalainen';'IT-päällikkö", " konsult';'Inkoo';'VIHR';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'Mukana inkoolaisten Vihreiden yhteismainonnassa jonka kokonaiskulut n. 1500 €", " osuus siitä siis noin 250 €; omaa rahaa facebook-mainontaan n. 25 €'"]
#
# Line 5271: 4 fields
# Raw content: ["'0054';'049';'Jonna Doris Anét';'Löflund';'yrittäjä", " LKV';'Espoo';'PS';'';'X';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';' ';'';'';'1. Vaalikampanjan kulut yhteensä 681 eur - Vaalimainonta: Sanoma-", ' ilmaisjakelu- ja aikakauslehdet 195 eur; Tietoverkot 75 eur; Vaalilehtien', " esitteiden ja muun painetun materiaalin hankinta 346 eur - Muut kulut: 65 eur 2. Vaalikampanjan rahoitus yhteensä 681 eur 2.1 Rahoitus sisältää omia varoja yhteensä 581 eur 2.6 Rahoitus sisältää puolueyhdistyksiltä saatua tukea yhteensä 100 eur'"]
#
# Line 5376: 7 fields
# Raw content: ["'0664';'049';'Jarkko Erik';'Rahkonen';'vanhusneuvoston varapuheenjohtaja", " toimitusjohtaja';'Espoo';'SDP';'Kauklahden sos.dem.yhd. ry';'';'5366';'3722';'0';'0';'145';'0';'0';'1439';'0';'0';'0';'60';'5366';'3926';'0';'1140';'X';'11hlö/ 20ex11=220e ;6hlö/50ex6=300e ;4hlö/80ex4=320e ;3hlö/ 100ex3=300e  YHT;1140e';'0';'X';'Yrityksiltä ei yhtään tukea';'0';'X';'';'300';' ';'Kauklhden sos", 'dem', 'yhd', "ry osuus viiden ehokaan yhteisesiteestä 300e';'0';'X';'Ei tukeaa muilta tahoilta", ' Vaimo tukena vapaaehtoisena talkoolaisena', "';'0';''"]
